# %% [markdown]
# <a href="https://colab.research.google.com/github/tomioka0802/Movies-Recommendation-Engines/blob/main/commit_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Setting Up Kaggle API For Downloading Dataset**

# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ~/.kaggle

# %%
# !ls /
# Out:
# bin			    datalab  kaggle  libx32		       opt   sbin  tools
# boot			    dev      lib     media		       proc  srv   usr
# content			    etc      lib32   mnt		       root  sys   var
# cuda-keyring_1.0-1_all.deb  home     lib64   NGC-DL-CONTAINER-LICENSE  run   tmp

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download rounakbanik/the-movies-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset
# License(s): CC0-1.0
# ...
#  99% 226M/228M [00:01<00:00, 218MB/s]
# 100% 228M/228M [00:01<00:00, 214MB/s]

# %%
# !unzip /content/the-movies-dataset.zip
# Out:
# Archive:  /content/the-movies-dataset.zip
#   inflating: credits.csv
#   inflating: keywords.csv
#   inflating: links.csv
#   inflating: links_small.csv
#   inflating: movies_metadata.csv
#   inflating: ratings.csv
#   inflating: ratings_small.csv

# %%
# %cd /content/drive/MyDrive/
# %mkdir "Movies Dataset"
# %cd /content/
# Out:
# /content/drive/MyDrive
# /content

# %%
# !cp /content/the-movies-dataset.zip /content/drive/MyDrive/Movies\ Dataset/

# %%
# %cd /content/drive/MyDrive/Movies Dataset
# %mkdir files
# !unzip the-movies-dataset.zip -d /content/drive/MyDrive/Movies\ Dataset/files
# Out:
# /content/drive/MyDrive/Movies Dataset
# Archive:  the-movies-dataset.zip
#   inflating: /content/drive/MyDrive/Movies Dataset/files/credits.csv
#   inflating: /content/drive/MyDrive/Movies Dataset/files/keywords.csv
#   inflating: /content/drive/MyDrive/Movies Dataset/files/links.csv
#   inflating: /content/drive/MyDrive/Movies Dataset/files/links_small.csv
#   inflating: /content/drive/MyDrive/Movies Dataset/files/movies_metadata.csv
#   inflating: /content/drive/MyDrive/Movies Dataset/files/ratings.csv
#   inflating: /content/drive/MyDrive/Movies Dataset/files/ratings_small.csv

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# # **2. Dataset Visualization**

# %%
# !ls /content/drive/MyDrive/Movies\ Dataset/files/
# Out:
# credits.csv   links.csv        movies_metadata.csv  ratings_small.csv
# keywords.csv  links_small.csv  ratings.csv

# %%
dataset_loc = "/content/drive/MyDrive/Movies Dataset/files"

import pandas as pd
credits_df = pd.read_csv(f'{dataset_loc}/credits.csv')
keywords_df = pd.read_csv(f'{dataset_loc}/keywords.csv')
links_df = pd.read_csv(f'{dataset_loc}/links.csv')
links_small_df = pd.read_csv(f'{dataset_loc}/links_small.csv')
movies_metadata_df = pd.read_csv(f'{dataset_loc}/movies_metadata.csv')
ratings_df = pd.read_csv(f'{dataset_loc}/ratings.csv')
ratings_small_df = pd.read_csv(f'{dataset_loc}/ratings_small.csv')
# Out:
# <ipython-input-29-3ef71e5dc47a>:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata_df = pd.read_csv(f'{dataset_loc}/movies_metadata.csv')

# %% [markdown]
# ### **2.1 Credits**

# %%
credits_df
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %% [markdown]
# ### **2.2 Keywords**

# %%
keywords_df
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %% [markdown]
# ### **2.3 Links**

# %%
links_df
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %% [markdown]
# ### **2.4 Links Small**

# %%
links_small_df
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0
#
# [9125 rows x 3 columns]

# %% [markdown]
# ### **2.5 Movies Metadata**

# %%
movies_metadata_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# ### **2.6 Ratings**

# %%
ratings_df
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %% [markdown]
# ### **2.7 Ratings Small**

# %%
ratings_small_df
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %% [markdown]
# # **3. Exploratory Data Analysis**
